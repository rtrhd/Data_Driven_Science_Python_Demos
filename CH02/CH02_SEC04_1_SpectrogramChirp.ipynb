# %%
import numpy as np
from numpy import pi as π

import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 18

# %%
dt = 0.001
t = np.arange(0, 2, dt)
f0 = 50
f1 = 250
t1 = 2
x = np.cos(2*π * t * (f0 + (f1 - f0) * t**2 / (3 * t1**2)))

fig, ax = plt.subplots(figsize=(12, 8))
sg = ax.specgram(x, NFFT=128, Fs=1/dt, noverlap=120, cmap='turbo')
fig.colorbar(sg[-1]);
